# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
import seaborn as sn
# Out:
# 2023-03-19 18:53:04.658981: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-19 18:53:04.776511: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-19 18:53:04.776543: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-19 18:53:04.796876: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-03-19 18:53:05.403917: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-19 18:53:05.403992: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-19 18:53:05.403998: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv("data.csv", index_col=0)
df.tail()
# Out:
#                                                   index  \
# 1995  [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 1...
# 1996  [25, 25, 25, 25, 24, 24, 24, 23, 22, 21, 20, 1...
# 1997  [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 1...
# 1998  [13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 1...
# 1999  [15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 1...
#
#                                                  middle  \
# 1995  [17, 17, 17, 16, 16, 16, 16, 16, 15, 15, 14, 1...
# 1996  [37, 37, 37, 37, 37, 36, 35, 34, 33, 31, 29, 2...
# 1997  [27, 27, 27, 27, 26, 26, 25, 25, 24, 24, 23, 2...
# 1998  [14, 14, 14, 14, 14, 14, 14, 13, 13, 13, 13, 1...
# 1999  [17, 17, 17, 17, 16, 16, 16, 16, 16, 16, 15, 1...
#
#                                                    ring  \
# 1995  [15, 14, 14, 14, 14, 13, 12, 12, 11, 10, 9, 8,...
# 1996  [21, 21, 21, 20, 18, 17, 15, 13, 11, 9, 6, 4, ...
# 1997  [14, 13, 13, 13, 12, 11, 11, 10, 9, 8, 6, 5, 3...
# 1998  [10, 10, 10, 10, 9, 9, 8, 7, 7, 6, 5, 4, 3, 2,...
# 1999  [6, 6, 6, 6, 6, 6, 5, 5, 4, 4, 3, 2, 1, 1, 0, ...
#
#                                                   pinky label
# 1995  [13, 13, 13, 13, 13, 12, 12, 11, 11, 10, 9, 8,...   1-2
# 1996  [26, 25, 25, 24, 23, 22, 20, 19, 17, 15, 12, 1...   1-2
# 1997  [17, 17, 17, 16, 16, 15, 14, 14, 13, 12, 10, 9...   1-2
# 1998  [9, 9, 9, 9, 9, 8, 8, 8, 7, 7, 6, 5, 5, 4, 3, ...   1-2
# 1999  [6, 6, 6, 6, 6, 6, 6, 5, 5, 5, 5, 5, 4, 4, 3, ...   1-2

# %%
# visualize data
df_reduced = df.groupby('label', group_keys=False).apply(lambda df: df.sample(1))
fig, ax = plt.subplots(7,3)
fig.set_size_inches((12,21))
for i in range(20):
    row = df_reduced.iloc[i,:]
    r,c = i//3, i%3
    label = row["label"]
    ax[r,c].set_title(label)
    ax[r,c].plot(np.array(json.loads(row["index"])), label="index")
    ax[r,c].plot(np.array(json.loads(row["middle"])), label="middle")
    ax[r,c].plot(np.array(json.loads(row["ring"])), label="ring")
    ax[r,c].plot(np.array(json.loads(row["pinky"])), label="pinky")
    ax[r,c].legend()
plt.show()

# %% [markdown]
# # Data Processing

# %%
# data processing
## X
n_steps = len(json.loads(df.iloc[0,0]))
n_features = 4
X = np.empty((df.shape[0], n_steps, n_features))
for i in range(X.shape[0]):    
    x = np.empty((n_steps, n_features))
    for j in range(n_features):
        arr = np.array(json.loads(df.iloc[i,j]))
        x[:,j] = arr
    X[i] = x
    
## y
labels = df["label"].to_numpy()
le = LabelEncoder()
y_encoded = le.fit_transform(labels)
n_classes = len(np.unique(y_encoded))
y = to_categorical(y_encoded)

## split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

# %% [markdown]
# # Model Training

# %%
# define model
model = Sequential()
model.add(LSTM(128, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(LSTM(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(n_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 128)           68096
#
#  dropout (Dropout)           (None, 30, 128)           0
#
#  batch_normalization (BatchN  (None, 30, 128)          512
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense (Dense)               (None, 20)                2580
#
# =================================================================
# Total params: 203,284
# Trainable params: 202,772
# Non-trainable params: 512
# _________________________________________________________________
# 2023-03-19 18:53:14.840992: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-19 18:53:14.841222: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-19 18:53:14.841278: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-03-19 18:53:14.841314: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-03-19 18:53:14.841349: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-03-19 18:53:14.857310: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-03-19 18:53:14.857480: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-03-19 18:53:14.857757: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
n_epochs = 100
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=n_epochs, batch_size=128)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 2s 108ms/step - loss: 2.1714 - accuracy: 0.3582 - val_loss: 2.7550 - val_accuracy: 0.4071
# Epoch 2/100
# 8/8 [==============================] - 1s 65ms/step - loss: 1.1021 - accuracy: 0.6857 - val_loss: 2.0826 - val_accuracy: 0.5190
# Epoch 3/100
# 8/8 [==============================] - 1s 68ms/step - loss: 0.7153 - accuracy: 0.8082 - val_loss: 1.4455 - val_accuracy: 0.6024
# Epoch 4/100
# 8/8 [==============================] - 0s 64ms/step - loss: 0.5416 - accuracy: 0.8347 - val_loss: 1.1113 - val_accuracy: 0.7214
# Epoch 5/100
# 8/8 [==============================] - 0s 63ms/step - loss: 0.4222 - accuracy: 0.8612 - val_loss: 1.0644 - val_accuracy: 0.7405
# Epoch 6/100
# 8/8 [==============================] - 1s 68ms/step - loss: 0.3242 - accuracy: 0.9163 - val_loss: 1.0057 - val_accuracy: 0.7786
# Epoch 7/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.2717 - accuracy: 0.9163 - val_loss: 0.9019 - val_accuracy: 0.8071
# Epoch 8/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2368 - accuracy: 0.9296 - val_loss: 0.8383 - val_accuracy: 0.8333
# Epoch 9/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.2171 - accuracy: 0.9306 - val_loss: 0.8482 - val_accuracy: 0.8214
# Epoch 10/100
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2041 - accuracy: 0.9388 - val_loss: 0.7895 - val_accuracy: 0.8476
# Epoch 11/100
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1759 - accuracy: 0.9500 - val_loss: 0.7216 - val_accuracy: 0.8571
# Epoch 12/100
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1699 - accuracy: 0.9510 - val_loss: 0.6909 - val_accuracy: 0.8524
# Epoch 13/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1632 - accuracy: 0.9469 - val_loss: 0.6876 - val_accuracy: 0.8833
# Epoch 14/100
# 8/8 [==============================] - 0s 64ms/step - loss: 0.1273 - accuracy: 0.9633 - val_loss: 0.6465 - val_accuracy: 0.8810
# Epoch 15/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1248 - accuracy: 0.9694 - val_loss: 0.5769 - val_accuracy: 0.8905
# Epoch 16/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1181 - accuracy: 0.9673 - val_loss: 0.5651 - val_accuracy: 0.8929
# Epoch 17/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1102 - accuracy: 0.9704 - val_loss: 0.4977 - val_accuracy: 0.9000
# Epoch 18/100
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1064 - accuracy: 0.9653 - val_loss: 0.4477 - val_accuracy: 0.9000
# Epoch 19/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1079 - accuracy: 0.9714 - val_loss: 0.4701 - val_accuracy: 0.9095
# Epoch 20/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0862 - accuracy: 0.9735 - val_loss: 0.4698 - val_accuracy: 0.8881
# Epoch 21/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0904 - accuracy: 0.9714 - val_loss: 0.4478 - val_accuracy: 0.9095
# Epoch 22/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0920 - accuracy: 0.9735 - val_loss: 0.4543 - val_accuracy: 0.8976
# Epoch 23/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0867 - accuracy: 0.9745 - val_loss: 0.3839 - val_accuracy: 0.9190
# Epoch 24/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0988 - accuracy: 0.9673 - val_loss: 0.3934 - val_accuracy: 0.8976
# Epoch 25/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0841 - accuracy: 0.9755 - val_loss: 0.3937 - val_accuracy: 0.9071
# Epoch 26/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0822 - accuracy: 0.9745 - val_loss: 0.3570 - val_accuracy: 0.9167
# Epoch 27/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0714 - accuracy: 0.9776 - val_loss: 0.3415 - val_accuracy: 0.9143
# Epoch 28/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0611 - accuracy: 0.9827 - val_loss: 0.3375 - val_accuracy: 0.9000
# Epoch 29/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0567 - accuracy: 0.9857 - val_loss: 0.2600 - val_accuracy: 0.9357
# Epoch 30/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0629 - accuracy: 0.9806 - val_loss: 0.3439 - val_accuracy: 0.8833
# Epoch 31/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0590 - accuracy: 0.9796 - val_loss: 0.2780 - val_accuracy: 0.9167
# Epoch 32/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0682 - accuracy: 0.9827 - val_loss: 0.2812 - val_accuracy: 0.9238
# Epoch 33/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0568 - accuracy: 0.9857 - val_loss: 0.3598 - val_accuracy: 0.8929
# Epoch 34/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0803 - accuracy: 0.9816 - val_loss: 0.2993 - val_accuracy: 0.9167
# Epoch 35/100
# 8/8 [==============================] - 0s 64ms/step - loss: 0.0547 - accuracy: 0.9827 - val_loss: 0.2775 - val_accuracy: 0.9214
# Epoch 36/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0426 - accuracy: 0.9898 - val_loss: 0.2715 - val_accuracy: 0.9190
# Epoch 37/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0372 - accuracy: 0.9898 - val_loss: 0.2622 - val_accuracy: 0.9143
# Epoch 38/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0365 - accuracy: 0.9908 - val_loss: 0.3156 - val_accuracy: 0.8857
# Epoch 39/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0350 - accuracy: 0.9908 - val_loss: 0.2632 - val_accuracy: 0.9286
# Epoch 40/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0307 - accuracy: 0.9878 - val_loss: 0.2979 - val_accuracy: 0.9190
# Epoch 41/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0411 - accuracy: 0.9888 - val_loss: 0.3081 - val_accuracy: 0.9095
# Epoch 42/100
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0532 - accuracy: 0.9837 - val_loss: 0.2554 - val_accuracy: 0.9238
# Epoch 43/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0457 - accuracy: 0.9888 - val_loss: 0.3179 - val_accuracy: 0.9238
# Epoch 44/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0389 - accuracy: 0.9878 - val_loss: 0.2777 - val_accuracy: 0.9143
# Epoch 45/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0337 - accuracy: 0.9898 - val_loss: 0.2498 - val_accuracy: 0.9190
# Epoch 46/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0319 - accuracy: 0.9888 - val_loss: 0.2539 - val_accuracy: 0.9238
# Epoch 47/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0330 - accuracy: 0.9918 - val_loss: 0.2466 - val_accuracy: 0.9071
# Epoch 48/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0292 - accuracy: 0.9939 - val_loss: 0.2530 - val_accuracy: 0.9262
# Epoch 49/100
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0302 - accuracy: 0.9918 - val_loss: 0.2435 - val_accuracy: 0.9262
# Epoch 50/100
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0258 - accuracy: 0.9929 - val_loss: 0.2714 - val_accuracy: 0.9167
# Epoch 51/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0274 - accuracy: 0.9949 - val_loss: 0.2804 - val_accuracy: 0.9214
# Epoch 52/100
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0213 - accuracy: 0.9949 - val_loss: 0.3263 - val_accuracy: 0.9000
# Epoch 53/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0231 - accuracy: 0.9949 - val_loss: 0.3032 - val_accuracy: 0.9167
# Epoch 54/100
# 8/8 [==============================] - 0s 64ms/step - loss: 0.0215 - accuracy: 0.9918 - val_loss: 0.2872 - val_accuracy: 0.9143
# Epoch 55/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.2667 - val_accuracy: 0.9262
# Epoch 56/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0382 - accuracy: 0.9898 - val_loss: 0.2678 - val_accuracy: 0.9214
# Epoch 57/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0420 - accuracy: 0.9888 - val_loss: 0.3285 - val_accuracy: 0.9071
# Epoch 58/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0358 - accuracy: 0.9867 - val_loss: 0.2427 - val_accuracy: 0.9214
# Epoch 59/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0633 - accuracy: 0.9745 - val_loss: 0.4767 - val_accuracy: 0.8833
# Epoch 60/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0518 - accuracy: 0.9878 - val_loss: 0.2984 - val_accuracy: 0.9095
# Epoch 61/100
# 8/8 [==============================] - 0s 64ms/step - loss: 0.0514 - accuracy: 0.9847 - val_loss: 0.3426 - val_accuracy: 0.9214
# Epoch 62/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0462 - accuracy: 0.9847 - val_loss: 0.4206 - val_accuracy: 0.9048
# Epoch 63/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0378 - accuracy: 0.9898 - val_loss: 0.4082 - val_accuracy: 0.8905
# Epoch 64/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0473 - accuracy: 0.9827 - val_loss: 0.2792 - val_accuracy: 0.9167
# Epoch 65/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0290 - accuracy: 0.9929 - val_loss: 0.3924 - val_accuracy: 0.8857
# Epoch 66/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0363 - accuracy: 0.9908 - val_loss: 0.2609 - val_accuracy: 0.9143
# Epoch 67/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0186 - accuracy: 0.9980 - val_loss: 0.2457 - val_accuracy: 0.9262
# Epoch 68/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0245 - accuracy: 0.9918 - val_loss: 0.2598 - val_accuracy: 0.9310
# Epoch 69/100
# 8/8 [==============================] - 0s 64ms/step - loss: 0.0178 - accuracy: 0.9959 - val_loss: 0.3429 - val_accuracy: 0.9024
# Epoch 70/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0151 - accuracy: 0.9990 - val_loss: 0.2662 - val_accuracy: 0.9310
# Epoch 71/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0091 - accuracy: 0.9990 - val_loss: 0.3365 - val_accuracy: 0.9095
# Epoch 72/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0112 - accuracy: 0.9969 - val_loss: 0.3274 - val_accuracy: 0.9048
# Epoch 73/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0256 - accuracy: 0.9929 - val_loss: 0.3466 - val_accuracy: 0.9048
# Epoch 74/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0419 - accuracy: 0.9867 - val_loss: 0.3256 - val_accuracy: 0.9143
# Epoch 75/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0289 - accuracy: 0.9898 - val_loss: 0.2808 - val_accuracy: 0.9119
# Epoch 76/100
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0265 - accuracy: 0.9908 - val_loss: 0.2332 - val_accuracy: 0.9333
# Epoch 77/100
# 8/8 [==============================] - 0s 64ms/step - loss: 0.0265 - accuracy: 0.9929 - val_loss: 0.2684 - val_accuracy: 0.9333
# Epoch 78/100
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0246 - accuracy: 0.9918 - val_loss: 0.3177 - val_accuracy: 0.9238
# Epoch 79/100
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0398 - accuracy: 0.9908 - val_loss: 0.4128 - val_accuracy: 0.9024
# Epoch 80/100
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0407 - accuracy: 0.9857 - val_loss: 0.3230 - val_accuracy: 0.9024
# Epoch 81/100
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0365 - accuracy: 0.9888 - val_loss: 0.2522 - val_accuracy: 0.9429
# Epoch 82/100
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0233 - accuracy: 0.9929 - val_loss: 0.2590 - val_accuracy: 0.9333
# Epoch 83/100
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0265 - accuracy: 0.9908 - val_loss: 0.3275 - val_accuracy: 0.9190
# Epoch 84/100
# 8/8 [==============================] - 1s 69ms/step - loss: 0.0152 - accuracy: 0.9949 - val_loss: 0.3451 - val_accuracy: 0.9167
# Epoch 85/100
# 8/8 [==============================] - 1s 69ms/step - loss: 0.0164 - accuracy: 0.9969 - val_loss: 0.2790 - val_accuracy: 0.9214
# Epoch 86/100
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0342 - accuracy: 0.9918 - val_loss: 0.2485 - val_accuracy: 0.9476
# Epoch 87/100
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0292 - accuracy: 0.9918 - val_loss: 0.2428 - val_accuracy: 0.9381
# Epoch 88/100
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0184 - accuracy: 0.9939 - val_loss: 0.2680 - val_accuracy: 0.9333
# Epoch 89/100
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.2815 - val_accuracy: 0.9286
# Epoch 90/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0132 - accuracy: 0.9980 - val_loss: 0.3130 - val_accuracy: 0.9119
# Epoch 91/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0109 - accuracy: 0.9980 - val_loss: 0.2576 - val_accuracy: 0.9405
# Epoch 92/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0166 - accuracy: 0.9939 - val_loss: 0.3910 - val_accuracy: 0.9024
# Epoch 93/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0115 - accuracy: 0.9990 - val_loss: 0.3088 - val_accuracy: 0.9214
# Epoch 94/100
# 8/8 [==============================] - 0s 63ms/step - loss: 0.0102 - accuracy: 0.9959 - val_loss: 0.2893 - val_accuracy: 0.9333
# Epoch 95/100
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.3364 - val_accuracy: 0.9190
# Epoch 96/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0078 - accuracy: 0.9990 - val_loss: 0.2691 - val_accuracy: 0.9310
# Epoch 97/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.2830 - val_accuracy: 0.9119
# Epoch 98/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0094 - accuracy: 0.9980 - val_loss: 0.3074 - val_accuracy: 0.9119
# Epoch 99/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.2521 - val_accuracy: 0.9262
# Epoch 100/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0188 - accuracy: 0.9939 - val_loss: 0.2795 - val_accuracy: 0.9167

# %% [markdown]
# # Model Evaluation

# %%
print("Train accuracy:", history.history["accuracy"][-1])
print("Validation accuracy:", history.history["val_accuracy"][-1])
print("Test accuracy:", model.evaluate(X_test, y_test, verbose=0)[1])
plt.plot(history.history["accuracy"], label="train")
plt.plot(history.history["val_accuracy"], label="val")
plt.legend()
plt.ylim((0,1))
plt.show()
# Out:
# Train accuracy: 0.9938775300979614
# Validation accuracy: 0.9166666865348816
# Test accuracy: 0.8899999856948853

# %%
y_pred = model.predict(X_test, verbose=0)
y_pred_rd = np.argmax(y_pred, axis=1)
y_test_rd = np.argmax(y_test, axis=1)
cm = confusion_matrix(y_test_rd, y_pred_rd)
df_cm = pd.DataFrame(cm, range(20), range(20))
plt.figure(figsize=(11,9))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %%
import time 

start = time.time()
y_prediction = model.predict(X_test) 
end = time.time()

print("Inference time: %f ms" % ((end - start)/X_test.shape[0] * 1000))
# Out:
# 19/19 [==============================] - 0s 11ms/step
# Inference time: 0.419006 ms
